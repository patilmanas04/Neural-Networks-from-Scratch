# %%
import numpy as np
import matplotlib.pyplot as plt
from nnfs.datasets import spiral_data

# %% [markdown]
# # Building and training of neural network with backpropagation, gradient descent, learning rate decay, ADAM Optimizer and L1/L2 regularization and dropout layer from scratch

# %% [markdown]
# ## Load the dataset

# %%
X, y = spiral_data(samples=100, classes=3)

print(X[:5])
print(y[:5])
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="brg")
plt.show()
# Out:
# [[ 0.          0.        ]
#  [-0.0019458   0.00991183]
#  [ 0.00260488  0.02003338]
#  [ 0.02218904 -0.02063783]
#  [ 0.03890051  0.01091956]]
# [0 0 0 0 0]

# %% [markdown]
# ## Dense Layer

# %%
class Layer_Dense:
    def __init__(self, n_inputs, n_neurons, weight_regularizer_l1=0., bias_regularizer_l1=0., weight_regularizer_l2=0., bias_regularizer_l2=0.):
        self.n_inputs = n_inputs
        self.n_neurons = n_neurons
        self.weights = 0.01 * np.random.rand(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
        self.weight_regularizer_l1 = weight_regularizer_l1 # lambda
        self.bias_regularizer_l1 = bias_regularizer_l1 # lambda
        self.weight_regularizer_l2 = weight_regularizer_l2 # lambda
        self.bias_regularizer_l2 = bias_regularizer_l2 # lambda

    # forward method
    def forward(self, inputs):
        self.inputs = inputs
        self.output = np.dot(inputs, self.weights) + self.biases

    # backward method (backpropagation)
    def backward(self, dL_dz):
        # Gradient of loss with respect to weights
        self.dL_dw = np.dot(self.inputs.T, dL_dz)

        # Gradient of loss with respect to biases
        self.dL_db = np.sum(dL_dz, axis=0, keepdims=True)

        # Gradient of loss with respect to inputs
        self.dL_dX = np.dot(dL_dz, self.weights.T)

        # Gradients of regularization
        # L1 weights
        if self.weight_regularizer_l1>0:
            dL1 = np.ones_like(self.weights)
            dL1[self.weights < 0] = -1
            self.dL_dw += self.weight_regularizer_l1 * dL1

        # L1 biases
        if self.bias_regularizer_l1>0:
            dL1 = np.ones_like(self.biases)
            dL1[self.biases < 0] = -1
            self.dL_db += self.bias_regularizer_l1 * dL1

        # L2 weights
        if self.weight_regularizer_l2>0:
            dL2 = 2 * self.weight_regularizer_l2 * self.weights
            self.dL_dw += dL2

        # L2 biases
        if self.bias_regularizer_l2>0:
            dL2 = 2 * self.bias_regularizer_l2 * self.biases
            self.dL_db += dL2

# %% [markdown]
# ## Dropout Layer

# %%
class Layer_Dropout:
    def __init__(self, dropout_rate=0):
        self.dropout_rate = 1 - dropout_rate

    def forward(self, inputs):
        self.inputs = inputs
        self.binary_mask = np.random.binomial(1, self.dropout_rate, size=inputs.shape) / self.dropout_rate
        self.output = self.inputs * self.binary_mask

    def backward(self, dL_dz):
        self.dL_dX = dL_dz * self.binary_mask

# %% [markdown]
# ## ReLU Activation

# %%
class Activation_ReLU:
    #forward method
    def forward(self, inputs):
        self.inputs = inputs
        self.output = np.maximum(0, inputs)

    # backward method (backpropagation)
    def backward(self, dL_da):
        self.dL_dz = dL_da.copy()

        # Gradient calculation
        self.dL_dz[self.inputs <= 0] = 0

# %% [markdown]
# ## Softmax Activation

# %%
class Activation_Softmax:
    def forward(self, final_layer_outputs):
        exp_values = np.exp(final_layer_outputs - np.max(final_layer_outputs, axis=1, keepdims=True))
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)
        self.output = probabilities

# %% [markdown]
# ## Loss function

# %%
class Loss:
    def regularization_loss(self, layer):
        regularization_loss = 0

        # L1 Regularization
        if layer.weight_regularizer_l1>0:
            regularization_loss += layer.weight_regularizer_l1 * np.sum(np.abs(layer.weights))
        if layer.bias_regularizer_l1>0:
            regularization_loss += layer.bias_regularizer_l1 * np.sum(np.abs(layer.biases))

        # L2 Regularization
        if layer.weight_regularizer_l2 > 0:
            regularization_loss += layer.weight_regularizer_l2 * np.sum(layer.weights * layer.weights)
        if layer.bias_regularizer_l2 > 0:
            regularization_loss += layer.bias_regularizer_l2 * np.sum(layer.biases * layer.biases)

        return regularization_loss
    
    def calculate(self, y_pred, y_true):
        neg_log_likelihoods = self.forward(y_pred, y_true)
        avg_loss = np.mean(neg_log_likelihoods)
        return avg_loss

class Loss_CategoricalCrossEntropy(Loss):
    def forward(self, y_pred, y_true):
        y_pred_clipped = np.clip(y_pred, 1e-7, 1-1e-7)

        if len(y_true.shape) == 1:
            correct_predictions = y_pred_clipped[range(len(y_pred_clipped)), y_true]
            
        if len(y_true.shape) == 2:
            correct_predictions = np.sum(y_pred_clipped*y_true, axis=1)

        neg_log_likelihoods = -np.log(correct_predictions)
        return neg_log_likelihoods

# %% [markdown]
# ## Combined Softmax Activation and Loss function

# %%
class Activation_Softmax_Loss_CategoricalCrossEntropy:
    def __init__(self):
        self.activation_softmax = Activation_Softmax()
        self.loss_function = Loss_CategoricalCrossEntropy()

    # forward method
    def forward(self, final_layer_output, y_true):
        self.activation_softmax.forward(final_layer_output)
        self.softmax_output = self.activation_softmax.output
        self.loss = self.loss_function.calculate(self.softmax_output, y_true)

        return self.loss

    # backward method (backpropagation)
    def backward(self, y_pred, y_true):
        no_of_batches = len(y_pred)
        
        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis=1)

        self.dL_dz = self.softmax_output.copy()

        # Gradient calculation
        self.dL_dz[range(no_of_batches), y_true] -= 1

        # Normalization
        self.dL_dz = self.dL_dz / no_of_batches

# %% [markdown]
# # ADAM Optimizer (Mostly used and most important) with decaying learning rate

# %%
class Optimizer_ADAM:
    def __init__(self, learning_rate=.001, decay=0, epsilon=1e-7, beta_1=0.9, beta_2=0.999):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay # learning rate decay factor
        self.epsilon = epsilon # To avoid divide by zero
        self.beta_1 = beta_1 # momentum factor
        self.beta_2 = beta_2 # rho: cache memory decay rate
        self.epoch = 0

    def pre_update_params(self):
        # learning rate decay
        self.current_learning_rate = self.learning_rate / (1. + self.decay*self.epoch)

    def update_params(self, layer):
        if not hasattr(layer, "weight_cache"):
            layer.weight_momentums = np.zeros_like(layer.weights)
            layer.weight_cache = np.zeros_like(layer.weights)
            layer.bias_momentums = np.zeros_like(layer.biases)
            layer.bias_cache = np.zeros_like(layer.biases)
            
        layer.weight_momentums = self.beta_1*layer.weight_momentums + (1-self.beta_1)*layer.dL_dw
        layer.bias_momentums = self.beta_1*layer.bias_momentums + (1-self.beta_1)*layer.dL_db

        layer.weight_cache = self.beta_2*layer.weight_cache + (1-self.beta_2)*layer.dL_dw**2
        layer.bias_cache = self.beta_2*layer.bias_cache + (1-self.beta_2)*layer.dL_db**2

        layer.weights += -self.current_learning_rate*(layer.weight_momentums/(1-self.beta_1**(self.epoch+1))) /\
                                                     (np.sqrt(layer.weight_cache/(1-self.beta_2**(self.epoch+1))) + self.epsilon)

        layer.biases += -self.current_learning_rate*(layer.bias_momentums/(1-self.beta_1**(self.epoch+1))) /\
                                                    (np.sqrt(layer.bias_cache/(1-self.beta_2**(self.epoch+1))) + self.epsilon)

    def post_update_params(self):
        self.epoch += 1

# %% [markdown]
# ## Training the neural network

# %%
# Defining the architecture
# dense_layer1 = Layer_Dense(2, 64)
dense_layer1 = Layer_Dense(2, 128, weight_regularizer_l2=5e-4, bias_regularizer_l2=5e-4)
activation_relu = Activation_ReLU()
dropout_layer1 = Layer_Dropout(dropout_rate=0.1)
dense_layer2 = Layer_Dense(128, 3)
softmax_loss = Activation_Softmax_Loss_CategoricalCrossEntropy()

# SGS Optimizer
optimizer_adam = Optimizer_ADAM(learning_rate=0.02, decay=5e-7)

loss_history = []
acc_history = []

for epoch in range(10001):
    # entire forward pass
    dense_layer1.forward(X)
    activation_relu.forward(dense_layer1.output)
    dropout_layer1.forward(activation_relu.output)
    dense_layer2.forward(dropout_layer1.output)
    softmax_loss.forward(final_layer_output=dense_layer2.output, y_true=y)

    data_loss = softmax_loss.loss
    regularization_loss = (
        softmax_loss.loss_function.regularization_loss(dense_layer1) +
        softmax_loss.loss_function.regularization_loss(dense_layer2)
    )
    loss = data_loss + regularization_loss
    loss_history.append(loss)

    predictions = np.argmax(softmax_loss.softmax_output, axis=1)
    accuracy = np.mean(predictions == y)
    acc_history.append(accuracy)

    if epoch % 100 == 0:
        print(f'Epoch: {epoch} Accuracy: {accuracy:.3f} Loss: {loss:.3f} (data_loss: {data_loss:.3f} regularization_loss: {regularization_loss:.3f}) lr: {optimizer_adam.current_learning_rate:.7f}')

    # entire backward pass (backpropagation)
    softmax_loss.backward(softmax_loss.softmax_output, y)
    dense_layer2.backward(dL_dz=softmax_loss.dL_dz)
    dropout_layer1.backward(dL_dz=dense_layer2.dL_dX)
    activation_relu.backward(dL_da=dropout_layer1.dL_dX)
    dense_layer1.backward(dL_dz=activation_relu.dL_dz)

    # Applying optimizer (Gradient descent with decaying learning rate and momentum)
    optimizer_adam.pre_update_params()
    optimizer_adam.update_params(dense_layer1)
    optimizer_adam.update_params(dense_layer2)
    optimizer_adam.post_update_params()

plt.plot(loss_history)
plt.title("Graph of Loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

plt.plot(acc_history)
plt.title("Graph of Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.show()

# Testing the neural network on new data
X_test, y_test = spiral_data(samples=100, classes=3)

# forward pass with test data
dense_layer1.forward(X_test)
activation_relu.forward(dense_layer1.output)
dense_layer2.forward(activation_relu.output)
softmax_loss.forward(final_layer_output=dense_layer2.output, y_true=y_test)

loss = softmax_loss.loss
predictions = np.argmax(softmax_loss.softmax_output, axis=1)
accuracy = np.mean(predictions == y)

print(f"Validation accuracy: {accuracy} Validation loss: {loss}")
# Out:
# Epoch: 0 Accuracy: 0.360 Loss: 1.099 (data_loss: 1.099 regularization_loss: 0.000) lr: 0.0200000
# Epoch: 100 Accuracy: 0.577 Loss: 0.901 (data_loss: 0.879 regularization_loss: 0.022) lr: 0.0199990
# Epoch: 200 Accuracy: 0.677 Loss: 0.757 (data_loss: 0.718 regularization_loss: 0.040) lr: 0.0199980
# Epoch: 300 Accuracy: 0.680 Loss: 0.729 (data_loss: 0.682 regularization_loss: 0.047) lr: 0.0199970
# Epoch: 400 Accuracy: 0.697 Loss: 0.710 (data_loss: 0.659 regularization_loss: 0.051) lr: 0.0199960
# Epoch: 500 Accuracy: 0.683 Loss: 0.733 (data_loss: 0.681 regularization_loss: 0.052) lr: 0.0199950
# Epoch: 600 Accuracy: 0.700 Loss: 0.695 (data_loss: 0.641 regularization_loss: 0.053) lr: 0.0199940
# Epoch: 700 Accuracy: 0.700 Loss: 0.677 (data_loss: 0.623 regularization_loss: 0.054) lr: 0.0199930
# Epoch: 800 Accuracy: 0.730 Loss: 0.658 (data_loss: 0.604 regularization_loss: 0.055) lr: 0.0199920
# Epoch: 900 Accuracy: 0.693 Loss: 0.706 (data_loss: 0.651 regularization_loss: 0.055) lr: 0.0199910
# Epoch: 1000 Accuracy: 0.697 Loss: 0.715 (data_loss: 0.659 regularization_loss: 0.056) lr: 0.0199900
# Epoch: 1100 Accuracy: 0.753 Loss: 0.713 (data_loss: 0.658 regularization_loss: 0.056) lr: 0.0199890
# Epoch: 1200 Accuracy: 0.737 Loss: 0.656 (data_loss: 0.601 regularization_loss: 0.055) lr: 0.0199880
# Epoch: 1300 Accuracy: 0.727 Loss: 0.621 (data_loss: 0.566 regularization_loss: 0.055) lr: 0.0199870
# Epoch: 1400 Accuracy: 0.727 Loss: 0.625 (data_loss: 0.570 regularization_loss: 0.055) lr: 0.0199860
# Epoch: 1500 Accuracy: 0.757 Loss: 0.613 (data_loss: 0.558 regularization_loss: 0.055) lr: 0.0199850
# Epoch: 1600 Accuracy: 0.733 Loss: 0.612 (data_loss: 0.557 regularization_loss: 0.055) lr: 0.0199840
# Epoch: 1700 Accuracy: 0.733 Loss: 0.612 (data_loss: 0.558 regularization_loss: 0.055) lr: 0.0199830
# Epoch: 1800 Accuracy: 0.757 Loss: 0.628 (data_loss: 0.573 regularization_loss: 0.055) lr: 0.0199820
# Epoch: 1900 Accuracy: 0.747 Loss: 0.700 (data_loss: 0.645 regularization_loss: 0.055) lr: 0.0199810
# Epoch: 2000 Accuracy: 0.730 Loss: 0.652 (data_loss: 0.597 regularization_loss: 0.055) lr: 0.0199800
# Epoch: 2100 Accuracy: 0.757 Loss: 0.615 (data_loss: 0.561 regularization_loss: 0.055) lr: 0.0199790
# Epoch: 2200 Accuracy: 0.763 Loss: 0.583 (data_loss: 0.528 regularization_loss: 0.055) lr: 0.0199780
# Epoch: 2300 Accuracy: 0.787 Loss: 0.612 (data_loss: 0.557 regularization_loss: 0.055) lr: 0.0199770
# Epoch: 2400 Accuracy: 0.757 Loss: 0.607 (data_loss: 0.552 regularization_loss: 0.055) lr: 0.0199760
# Epoch: 2500 Accuracy: 0.783 Loss: 0.588 (data_loss: 0.533 regularization_loss: 0.055) lr: 0.0199750
# Epoch: 2600 Accuracy: 0.733 Loss: 0.591 (data_loss: 0.536 regularization_loss: 0.055) lr: 0.0199740
# Epoch: 2700 Accuracy: 0.747 Loss: 0.629 (data_loss: 0.574 regularization_loss: 0.055) lr: 0.0199730
# Epoch: 2800 Accuracy: 0.773 Loss: 0.644 (data_loss: 0.589 regularization_loss: 0.055) lr: 0.0199720
# Epoch: 2900 Accuracy: 0.733 Loss: 0.634 (data_loss: 0.580 regularization_loss: 0.055) lr: 0.0199711
# Epoch: 3000 Accuracy: 0.783 Loss: 0.592 (data_loss: 0.537 regularization_loss: 0.055) lr: 0.0199701
# Epoch: 3100 Accuracy: 0.787 Loss: 0.556 (data_loss: 0.502 regularization_loss: 0.054) lr: 0.0199691
# Epoch: 3200 Accuracy: 0.780 Loss: 0.562 (data_loss: 0.507 regularization_loss: 0.054) lr: 0.0199681
# Epoch: 3300 Accuracy: 0.777 Loss: 0.633 (data_loss: 0.579 regularization_loss: 0.054) lr: 0.0199671
# Epoch: 3400 Accuracy: 0.793 Loss: 0.572 (data_loss: 0.518 regularization_loss: 0.054) lr: 0.0199661
# Epoch: 3500 Accuracy: 0.780 Loss: 0.607 (data_loss: 0.553 regularization_loss: 0.054) lr: 0.0199651
# Epoch: 3600 Accuracy: 0.770 Loss: 0.561 (data_loss: 0.507 regularization_loss: 0.054) lr: 0.0199641
# Epoch: 3700 Accuracy: 0.780 Loss: 0.535 (data_loss: 0.481 regularization_loss: 0.054) lr: 0.0199631
# Epoch: 3800 Accuracy: 0.800 Loss: 0.570 (data_loss: 0.515 regularization_loss: 0.054) lr: 0.0199621
# Epoch: 3900 Accuracy: 0.767 Loss: 0.583 (data_loss: 0.529 regularization_loss: 0.054) lr: 0.0199611
# Epoch: 4000 Accuracy: 0.780 Loss: 0.600 (data_loss: 0.547 regularization_loss: 0.054) lr: 0.0199601
# Epoch: 4100 Accuracy: 0.790 Loss: 0.569 (data_loss: 0.514 regularization_loss: 0.054) lr: 0.0199591
# Epoch: 4200 Accuracy: 0.773 Loss: 0.557 (data_loss: 0.503 regularization_loss: 0.054) lr: 0.0199581
# Epoch: 4300 Accuracy: 0.783 Loss: 0.593 (data_loss: 0.539 regularization_loss: 0.053) lr: 0.0199571
# Epoch: 4400 Accuracy: 0.783 Loss: 0.579 (data_loss: 0.525 regularization_loss: 0.054) lr: 0.0199561
# Epoch: 4500 Accuracy: 0.743 Loss: 0.619 (data_loss: 0.565 regularization_loss: 0.054) lr: 0.0199551
# Epoch: 4600 Accuracy: 0.770 Loss: 0.615 (data_loss: 0.561 regularization_loss: 0.054) lr: 0.0199541
# Epoch: 4700 Accuracy: 0.783 Loss: 0.534 (data_loss: 0.480 regularization_loss: 0.054) lr: 0.0199531
# Epoch: 4800 Accuracy: 0.790 Loss: 0.613 (data_loss: 0.559 regularization_loss: 0.053) lr: 0.0199521
# Epoch: 4900 Accuracy: 0.810 Loss: 0.541 (data_loss: 0.487 regularization_loss: 0.054) lr: 0.0199511
# Epoch: 5000 Accuracy: 0.777 Loss: 0.565 (data_loss: 0.512 regularization_loss: 0.053) lr: 0.0199501
# Epoch: 5100 Accuracy: 0.773 Loss: 0.566 (data_loss: 0.513 regularization_loss: 0.053) lr: 0.0199491
# Epoch: 5200 Accuracy: 0.803 Loss: 0.499 (data_loss: 0.446 regularization_loss: 0.054) lr: 0.0199481
# Epoch: 5300 Accuracy: 0.780 Loss: 0.654 (data_loss: 0.601 regularization_loss: 0.053) lr: 0.0199472
# Epoch: 5400 Accuracy: 0.753 Loss: 0.660 (data_loss: 0.606 regularization_loss: 0.054) lr: 0.0199462
# Epoch: 5500 Accuracy: 0.793 Loss: 0.541 (data_loss: 0.488 regularization_loss: 0.054) lr: 0.0199452
# Epoch: 5600 Accuracy: 0.810 Loss: 0.520 (data_loss: 0.466 regularization_loss: 0.054) lr: 0.0199442
# Epoch: 5700 Accuracy: 0.777 Loss: 0.674 (data_loss: 0.621 regularization_loss: 0.053) lr: 0.0199432
# Epoch: 5800 Accuracy: 0.797 Loss: 0.508 (data_loss: 0.454 regularization_loss: 0.053) lr: 0.0199422
# Epoch: 5900 Accuracy: 0.773 Loss: 0.569 (data_loss: 0.516 regularization_loss: 0.053) lr: 0.0199412
# Epoch: 6000 Accuracy: 0.767 Loss: 0.548 (data_loss: 0.495 regularization_loss: 0.053) lr: 0.0199402
# Epoch: 6100 Accuracy: 0.780 Loss: 0.511 (data_loss: 0.458 regularization_loss: 0.053) lr: 0.0199392
# Epoch: 6200 Accuracy: 0.793 Loss: 0.538 (data_loss: 0.484 regularization_loss: 0.054) lr: 0.0199382
# Epoch: 6300 Accuracy: 0.780 Loss: 0.594 (data_loss: 0.540 regularization_loss: 0.053) lr: 0.0199372
# Epoch: 6400 Accuracy: 0.777 Loss: 0.554 (data_loss: 0.501 regularization_loss: 0.053) lr: 0.0199362
# Epoch: 6500 Accuracy: 0.817 Loss: 0.547 (data_loss: 0.494 regularization_loss: 0.054) lr: 0.0199352
# Epoch: 6600 Accuracy: 0.783 Loss: 0.555 (data_loss: 0.502 regularization_loss: 0.053) lr: 0.0199342
# Epoch: 6700 Accuracy: 0.800 Loss: 0.544 (data_loss: 0.491 regularization_loss: 0.053) lr: 0.0199332
# Epoch: 6800 Accuracy: 0.783 Loss: 0.559 (data_loss: 0.506 regularization_loss: 0.053) lr: 0.0199322
# Epoch: 6900 Accuracy: 0.757 Loss: 0.610 (data_loss: 0.557 regularization_loss: 0.053) lr: 0.0199312
# Epoch: 7000 Accuracy: 0.770 Loss: 0.520 (data_loss: 0.467 regularization_loss: 0.053) lr: 0.0199303
# Epoch: 7100 Accuracy: 0.813 Loss: 0.503 (data_loss: 0.450 regularization_loss: 0.053) lr: 0.0199293
# Epoch: 7200 Accuracy: 0.797 Loss: 0.511 (data_loss: 0.458 regularization_loss: 0.053) lr: 0.0199283
# Epoch: 7300 Accuracy: 0.780 Loss: 0.612 (data_loss: 0.559 regularization_loss: 0.053) lr: 0.0199273
# Epoch: 7400 Accuracy: 0.817 Loss: 0.530 (data_loss: 0.476 regularization_loss: 0.053) lr: 0.0199263
# Epoch: 7500 Accuracy: 0.767 Loss: 0.597 (data_loss: 0.544 regularization_loss: 0.053) lr: 0.0199253
# Epoch: 7600 Accuracy: 0.777 Loss: 0.544 (data_loss: 0.491 regularization_loss: 0.053) lr: 0.0199243
# Epoch: 7700 Accuracy: 0.790 Loss: 0.608 (data_loss: 0.555 regularization_loss: 0.053) lr: 0.0199233
# Epoch: 7800 Accuracy: 0.790 Loss: 0.531 (data_loss: 0.477 regularization_loss: 0.054) lr: 0.0199223
# Epoch: 7900 Accuracy: 0.770 Loss: 0.497 (data_loss: 0.444 regularization_loss: 0.053) lr: 0.0199213
# Epoch: 8000 Accuracy: 0.800 Loss: 0.528 (data_loss: 0.475 regularization_loss: 0.053) lr: 0.0199203
# Epoch: 8100 Accuracy: 0.837 Loss: 0.510 (data_loss: 0.457 regularization_loss: 0.053) lr: 0.0199193
# Epoch: 8200 Accuracy: 0.800 Loss: 0.494 (data_loss: 0.441 regularization_loss: 0.053) lr: 0.0199183
# Epoch: 8300 Accuracy: 0.783 Loss: 0.588 (data_loss: 0.535 regularization_loss: 0.053) lr: 0.0199174
# Epoch: 8400 Accuracy: 0.820 Loss: 0.480 (data_loss: 0.426 regularization_loss: 0.053) lr: 0.0199164
# Epoch: 8500 Accuracy: 0.800 Loss: 0.531 (data_loss: 0.477 regularization_loss: 0.053) lr: 0.0199154
# Epoch: 8600 Accuracy: 0.787 Loss: 0.508 (data_loss: 0.454 regularization_loss: 0.054) lr: 0.0199144
# Epoch: 8700 Accuracy: 0.803 Loss: 0.502 (data_loss: 0.449 regularization_loss: 0.053) lr: 0.0199134
# Epoch: 8800 Accuracy: 0.827 Loss: 0.480 (data_loss: 0.426 regularization_loss: 0.053) lr: 0.0199124
# Epoch: 8900 Accuracy: 0.787 Loss: 0.546 (data_loss: 0.493 regularization_loss: 0.053) lr: 0.0199114
# Epoch: 9000 Accuracy: 0.833 Loss: 0.494 (data_loss: 0.441 regularization_loss: 0.053) lr: 0.0199104
# Epoch: 9100 Accuracy: 0.790 Loss: 0.559 (data_loss: 0.506 regularization_loss: 0.053) lr: 0.0199094
# Epoch: 9200 Accuracy: 0.780 Loss: 0.512 (data_loss: 0.459 regularization_loss: 0.053) lr: 0.0199084
# Epoch: 9300 Accuracy: 0.800 Loss: 0.495 (data_loss: 0.442 regularization_loss: 0.053) lr: 0.0199074
# Epoch: 9400 Accuracy: 0.807 Loss: 0.500 (data_loss: 0.446 regularization_loss: 0.053) lr: 0.0199064
# Epoch: 9500 Accuracy: 0.807 Loss: 0.495 (data_loss: 0.442 regularization_loss: 0.053) lr: 0.0199055
# Epoch: 9600 Accuracy: 0.807 Loss: 0.501 (data_loss: 0.449 regularization_loss: 0.053) lr: 0.0199045
# Epoch: 9700 Accuracy: 0.780 Loss: 0.593 (data_loss: 0.540 regularization_loss: 0.053) lr: 0.0199035
# Epoch: 9800 Accuracy: 0.807 Loss: 0.516 (data_loss: 0.463 regularization_loss: 0.053) lr: 0.0199025
# Epoch: 9900 Accuracy: 0.790 Loss: 0.614 (data_loss: 0.561 regularization_loss: 0.053) lr: 0.0199015
# Epoch: 10000 Accuracy: 0.807 Loss: 0.508 (data_loss: 0.455 regularization_loss: 0.053) lr: 0.0199005
# Validation accuracy: 0.7933333333333333 Validation loss: 0.6964097204415739

# %% [markdown]
# # Trainig with more sample points

# %%
X, y = spiral_data(samples=1000, classes=3)

# Defining the architecture
# dense_layer1 = Layer_Dense(2, 64)
dense_layer1 = Layer_Dense(2, 128, weight_regularizer_l2=5e-4, bias_regularizer_l2=5e-4)
activation_relu = Activation_ReLU()
dropout_layer1 = Layer_Dropout(dropout_rate=0.05)
dense_layer2 = Layer_Dense(128, 3)
softmax_loss = Activation_Softmax_Loss_CategoricalCrossEntropy()

# SGS Optimizer
optimizer_adam = Optimizer_ADAM(learning_rate=0.02, decay=5e-7)

loss_history = []
acc_history = []

for epoch in range(10001):
    # entire forward pass
    dense_layer1.forward(X)
    activation_relu.forward(dense_layer1.output)
    dropout_layer1.forward(activation_relu.output)
    dense_layer2.forward(dropout_layer1.output)
    softmax_loss.forward(final_layer_output=dense_layer2.output, y_true=y)

    data_loss = softmax_loss.loss
    regularization_loss = (
        softmax_loss.loss_function.regularization_loss(dense_layer1) +
        softmax_loss.loss_function.regularization_loss(dense_layer2)
    )
    loss = data_loss + regularization_loss
    loss_history.append(loss)

    predictions = np.argmax(softmax_loss.softmax_output, axis=1)
    accuracy = np.mean(predictions == y)
    acc_history.append(accuracy)

    if epoch % 100 == 0:
        print(f'Epoch: {epoch} Accuracy: {accuracy:.3f} Loss: {loss:.3f} (data_loss: {data_loss:.3f} regularization_loss: {regularization_loss:.3f}) lr: {optimizer_adam.current_learning_rate:.7f}')

    # entire backward pass (backpropagation)
    softmax_loss.backward(softmax_loss.softmax_output, y)
    dense_layer2.backward(dL_dz=softmax_loss.dL_dz)
    dropout_layer1.backward(dL_dz=dense_layer2.dL_dX)
    activation_relu.backward(dL_da=dropout_layer1.dL_dX)
    dense_layer1.backward(dL_dz=activation_relu.dL_dz)

    # Applying optimizer (Gradient descent with decaying learning rate and momentum)
    optimizer_adam.pre_update_params()
    optimizer_adam.update_params(dense_layer1)
    optimizer_adam.update_params(dense_layer2)
    optimizer_adam.post_update_params()

plt.plot(loss_history)
plt.title("Graph of Loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

plt.plot(acc_history)
plt.title("Graph of Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.show()

# Testing the neural network on new data
X_test, y_test = spiral_data(samples=1000, classes=3)

# forward pass with test data
dense_layer1.forward(X_test)
activation_relu.forward(dense_layer1.output)
dense_layer2.forward(activation_relu.output)
softmax_loss.forward(final_layer_output=dense_layer2.output, y_true=y_test)

loss = softmax_loss.loss
predictions = np.argmax(softmax_loss.softmax_output, axis=1)
accuracy = np.mean(predictions == y)

print(f"Validation accuracy: {accuracy} Validation loss: {loss}")
# Out:
# Epoch: 0 Accuracy: 0.338 Loss: 1.099 (data_loss: 1.099 regularization_loss: 0.000) lr: 0.0200000
# Epoch: 100 Accuracy: 0.637 Loss: 0.864 (data_loss: 0.828 regularization_loss: 0.037) lr: 0.0199990
# Epoch: 200 Accuracy: 0.714 Loss: 0.747 (data_loss: 0.690 regularization_loss: 0.057) lr: 0.0199980
# Epoch: 300 Accuracy: 0.745 Loss: 0.686 (data_loss: 0.623 regularization_loss: 0.063) lr: 0.0199970
# Epoch: 400 Accuracy: 0.755 Loss: 0.675 (data_loss: 0.610 regularization_loss: 0.065) lr: 0.0199960
# Epoch: 500 Accuracy: 0.767 Loss: 0.658 (data_loss: 0.592 regularization_loss: 0.065) lr: 0.0199950
# Epoch: 600 Accuracy: 0.782 Loss: 0.638 (data_loss: 0.574 regularization_loss: 0.064) lr: 0.0199940
# Epoch: 700 Accuracy: 0.784 Loss: 0.642 (data_loss: 0.580 regularization_loss: 0.062) lr: 0.0199930
# Epoch: 800 Accuracy: 0.787 Loss: 0.618 (data_loss: 0.557 regularization_loss: 0.061) lr: 0.0199920
# Epoch: 900 Accuracy: 0.790 Loss: 0.609 (data_loss: 0.550 regularization_loss: 0.059) lr: 0.0199910
# Epoch: 1000 Accuracy: 0.796 Loss: 0.597 (data_loss: 0.540 regularization_loss: 0.057) lr: 0.0199900
# Epoch: 1100 Accuracy: 0.804 Loss: 0.598 (data_loss: 0.542 regularization_loss: 0.056) lr: 0.0199890
# Epoch: 1200 Accuracy: 0.781 Loss: 0.598 (data_loss: 0.544 regularization_loss: 0.055) lr: 0.0199880
# Epoch: 1300 Accuracy: 0.805 Loss: 0.589 (data_loss: 0.535 regularization_loss: 0.054) lr: 0.0199870
# Epoch: 1400 Accuracy: 0.811 Loss: 0.572 (data_loss: 0.519 regularization_loss: 0.053) lr: 0.0199860
# Epoch: 1500 Accuracy: 0.811 Loss: 0.581 (data_loss: 0.529 regularization_loss: 0.052) lr: 0.0199850
# Epoch: 1600 Accuracy: 0.810 Loss: 0.574 (data_loss: 0.523 regularization_loss: 0.051) lr: 0.0199840
# Epoch: 1700 Accuracy: 0.805 Loss: 0.556 (data_loss: 0.507 regularization_loss: 0.050) lr: 0.0199830
# Epoch: 1800 Accuracy: 0.800 Loss: 0.585 (data_loss: 0.536 regularization_loss: 0.049) lr: 0.0199820
# Epoch: 1900 Accuracy: 0.808 Loss: 0.568 (data_loss: 0.520 regularization_loss: 0.048) lr: 0.0199810
# Epoch: 2000 Accuracy: 0.814 Loss: 0.562 (data_loss: 0.515 regularization_loss: 0.047) lr: 0.0199800
# Epoch: 2100 Accuracy: 0.810 Loss: 0.583 (data_loss: 0.537 regularization_loss: 0.047) lr: 0.0199790
# Epoch: 2200 Accuracy: 0.813 Loss: 0.555 (data_loss: 0.508 regularization_loss: 0.046) lr: 0.0199780
# Epoch: 2300 Accuracy: 0.819 Loss: 0.555 (data_loss: 0.509 regularization_loss: 0.046) lr: 0.0199770
# Epoch: 2400 Accuracy: 0.808 Loss: 0.562 (data_loss: 0.516 regularization_loss: 0.045) lr: 0.0199760
# Epoch: 2500 Accuracy: 0.825 Loss: 0.551 (data_loss: 0.506 regularization_loss: 0.045) lr: 0.0199750
# Epoch: 2600 Accuracy: 0.809 Loss: 0.554 (data_loss: 0.510 regularization_loss: 0.044) lr: 0.0199740
# Epoch: 2700 Accuracy: 0.809 Loss: 0.538 (data_loss: 0.494 regularization_loss: 0.044) lr: 0.0199730
# Epoch: 2800 Accuracy: 0.817 Loss: 0.562 (data_loss: 0.519 regularization_loss: 0.043) lr: 0.0199720
# Epoch: 2900 Accuracy: 0.812 Loss: 0.561 (data_loss: 0.518 regularization_loss: 0.043) lr: 0.0199711
# Epoch: 3000 Accuracy: 0.816 Loss: 0.547 (data_loss: 0.504 regularization_loss: 0.043) lr: 0.0199701
# Epoch: 3100 Accuracy: 0.815 Loss: 0.545 (data_loss: 0.503 regularization_loss: 0.042) lr: 0.0199691
# Epoch: 3200 Accuracy: 0.818 Loss: 0.547 (data_loss: 0.505 regularization_loss: 0.042) lr: 0.0199681
# Epoch: 3300 Accuracy: 0.828 Loss: 0.544 (data_loss: 0.503 regularization_loss: 0.041) lr: 0.0199671
# Epoch: 3400 Accuracy: 0.822 Loss: 0.547 (data_loss: 0.506 regularization_loss: 0.041) lr: 0.0199661
# Epoch: 3500 Accuracy: 0.820 Loss: 0.548 (data_loss: 0.507 regularization_loss: 0.040) lr: 0.0199651
# Epoch: 3600 Accuracy: 0.820 Loss: 0.531 (data_loss: 0.491 regularization_loss: 0.040) lr: 0.0199641
# Epoch: 3700 Accuracy: 0.817 Loss: 0.524 (data_loss: 0.484 regularization_loss: 0.040) lr: 0.0199631
# Epoch: 3800 Accuracy: 0.817 Loss: 0.537 (data_loss: 0.497 regularization_loss: 0.039) lr: 0.0199621
# Epoch: 3900 Accuracy: 0.831 Loss: 0.544 (data_loss: 0.505 regularization_loss: 0.039) lr: 0.0199611
# Epoch: 4000 Accuracy: 0.826 Loss: 0.516 (data_loss: 0.477 regularization_loss: 0.039) lr: 0.0199601
# Epoch: 4100 Accuracy: 0.813 Loss: 0.536 (data_loss: 0.497 regularization_loss: 0.038) lr: 0.0199591
# Epoch: 4200 Accuracy: 0.823 Loss: 0.554 (data_loss: 0.517 regularization_loss: 0.038) lr: 0.0199581
# Epoch: 4300 Accuracy: 0.823 Loss: 0.529 (data_loss: 0.491 regularization_loss: 0.038) lr: 0.0199571
# Epoch: 4400 Accuracy: 0.825 Loss: 0.531 (data_loss: 0.493 regularization_loss: 0.037) lr: 0.0199561
# Epoch: 4500 Accuracy: 0.821 Loss: 0.536 (data_loss: 0.499 regularization_loss: 0.037) lr: 0.0199551
# Epoch: 4600 Accuracy: 0.827 Loss: 0.525 (data_loss: 0.488 regularization_loss: 0.037) lr: 0.0199541
# Epoch: 4700 Accuracy: 0.821 Loss: 0.528 (data_loss: 0.491 regularization_loss: 0.037) lr: 0.0199531
# Epoch: 4800 Accuracy: 0.826 Loss: 0.523 (data_loss: 0.486 regularization_loss: 0.037) lr: 0.0199521
# Epoch: 4900 Accuracy: 0.821 Loss: 0.525 (data_loss: 0.489 regularization_loss: 0.036) lr: 0.0199511
# Epoch: 5000 Accuracy: 0.827 Loss: 0.502 (data_loss: 0.466 regularization_loss: 0.036) lr: 0.0199501
# Epoch: 5100 Accuracy: 0.820 Loss: 0.521 (data_loss: 0.486 regularization_loss: 0.036) lr: 0.0199491
# Epoch: 5200 Accuracy: 0.807 Loss: 0.528 (data_loss: 0.493 regularization_loss: 0.036) lr: 0.0199481
# Epoch: 5300 Accuracy: 0.819 Loss: 0.517 (data_loss: 0.482 regularization_loss: 0.036) lr: 0.0199472
# Epoch: 5400 Accuracy: 0.816 Loss: 0.548 (data_loss: 0.513 regularization_loss: 0.036) lr: 0.0199462
# Epoch: 5500 Accuracy: 0.827 Loss: 0.532 (data_loss: 0.497 regularization_loss: 0.035) lr: 0.0199452
# Epoch: 5600 Accuracy: 0.825 Loss: 0.513 (data_loss: 0.477 regularization_loss: 0.035) lr: 0.0199442
# Epoch: 5700 Accuracy: 0.825 Loss: 0.520 (data_loss: 0.485 regularization_loss: 0.035) lr: 0.0199432
# Epoch: 5800 Accuracy: 0.831 Loss: 0.515 (data_loss: 0.480 regularization_loss: 0.035) lr: 0.0199422
# Epoch: 5900 Accuracy: 0.828 Loss: 0.515 (data_loss: 0.480 regularization_loss: 0.035) lr: 0.0199412
# Epoch: 6000 Accuracy: 0.828 Loss: 0.513 (data_loss: 0.479 regularization_loss: 0.034) lr: 0.0199402
# Epoch: 6100 Accuracy: 0.826 Loss: 0.524 (data_loss: 0.490 regularization_loss: 0.034) lr: 0.0199392
# Epoch: 6200 Accuracy: 0.827 Loss: 0.517 (data_loss: 0.483 regularization_loss: 0.034) lr: 0.0199382
# Epoch: 6300 Accuracy: 0.831 Loss: 0.512 (data_loss: 0.478 regularization_loss: 0.034) lr: 0.0199372
# Epoch: 6400 Accuracy: 0.844 Loss: 0.504 (data_loss: 0.470 regularization_loss: 0.034) lr: 0.0199362
# Epoch: 6500 Accuracy: 0.836 Loss: 0.499 (data_loss: 0.465 regularization_loss: 0.034) lr: 0.0199352
# Epoch: 6600 Accuracy: 0.835 Loss: 0.517 (data_loss: 0.483 regularization_loss: 0.034) lr: 0.0199342
# Epoch: 6700 Accuracy: 0.833 Loss: 0.482 (data_loss: 0.448 regularization_loss: 0.034) lr: 0.0199332
# Epoch: 6800 Accuracy: 0.816 Loss: 0.511 (data_loss: 0.477 regularization_loss: 0.034) lr: 0.0199322
# Epoch: 6900 Accuracy: 0.822 Loss: 0.517 (data_loss: 0.483 regularization_loss: 0.034) lr: 0.0199312
# Epoch: 7000 Accuracy: 0.826 Loss: 0.521 (data_loss: 0.487 regularization_loss: 0.034) lr: 0.0199303
# Epoch: 7100 Accuracy: 0.831 Loss: 0.510 (data_loss: 0.477 regularization_loss: 0.034) lr: 0.0199293
# Epoch: 7200 Accuracy: 0.836 Loss: 0.491 (data_loss: 0.457 regularization_loss: 0.034) lr: 0.0199283
# Epoch: 7300 Accuracy: 0.834 Loss: 0.490 (data_loss: 0.456 regularization_loss: 0.034) lr: 0.0199273
# Epoch: 7400 Accuracy: 0.831 Loss: 0.494 (data_loss: 0.460 regularization_loss: 0.033) lr: 0.0199263
# Epoch: 7500 Accuracy: 0.831 Loss: 0.503 (data_loss: 0.470 regularization_loss: 0.033) lr: 0.0199253
# Epoch: 7600 Accuracy: 0.821 Loss: 0.518 (data_loss: 0.484 regularization_loss: 0.033) lr: 0.0199243
# Epoch: 7700 Accuracy: 0.826 Loss: 0.512 (data_loss: 0.479 regularization_loss: 0.033) lr: 0.0199233
# Epoch: 7800 Accuracy: 0.826 Loss: 0.510 (data_loss: 0.477 regularization_loss: 0.033) lr: 0.0199223
# Epoch: 7900 Accuracy: 0.830 Loss: 0.510 (data_loss: 0.477 regularization_loss: 0.033) lr: 0.0199213
# Epoch: 8000 Accuracy: 0.821 Loss: 0.518 (data_loss: 0.485 regularization_loss: 0.033) lr: 0.0199203
# Epoch: 8100 Accuracy: 0.838 Loss: 0.505 (data_loss: 0.473 regularization_loss: 0.033) lr: 0.0199193
# Epoch: 8200 Accuracy: 0.833 Loss: 0.515 (data_loss: 0.483 regularization_loss: 0.033) lr: 0.0199183
# Epoch: 8300 Accuracy: 0.833 Loss: 0.513 (data_loss: 0.481 regularization_loss: 0.032) lr: 0.0199174
# Epoch: 8400 Accuracy: 0.838 Loss: 0.519 (data_loss: 0.486 regularization_loss: 0.032) lr: 0.0199164
# Epoch: 8500 Accuracy: 0.828 Loss: 0.492 (data_loss: 0.460 regularization_loss: 0.032) lr: 0.0199154
# Epoch: 8600 Accuracy: 0.823 Loss: 0.505 (data_loss: 0.474 regularization_loss: 0.032) lr: 0.0199144
# Epoch: 8700 Accuracy: 0.827 Loss: 0.503 (data_loss: 0.472 regularization_loss: 0.032) lr: 0.0199134
# Epoch: 8800 Accuracy: 0.828 Loss: 0.502 (data_loss: 0.471 regularization_loss: 0.032) lr: 0.0199124
# Epoch: 8900 Accuracy: 0.829 Loss: 0.519 (data_loss: 0.488 regularization_loss: 0.032) lr: 0.0199114
# Epoch: 9000 Accuracy: 0.832 Loss: 0.508 (data_loss: 0.477 regularization_loss: 0.032) lr: 0.0199104
# Epoch: 9100 Accuracy: 0.827 Loss: 0.502 (data_loss: 0.470 regularization_loss: 0.031) lr: 0.0199094
# Epoch: 9200 Accuracy: 0.833 Loss: 0.501 (data_loss: 0.470 regularization_loss: 0.031) lr: 0.0199084
# Epoch: 9300 Accuracy: 0.829 Loss: 0.492 (data_loss: 0.461 regularization_loss: 0.031) lr: 0.0199074
# Epoch: 9400 Accuracy: 0.837 Loss: 0.518 (data_loss: 0.487 regularization_loss: 0.031) lr: 0.0199064
# Epoch: 9500 Accuracy: 0.833 Loss: 0.484 (data_loss: 0.453 regularization_loss: 0.031) lr: 0.0199055
# Epoch: 9600 Accuracy: 0.840 Loss: 0.498 (data_loss: 0.467 regularization_loss: 0.031) lr: 0.0199045
# Epoch: 9700 Accuracy: 0.839 Loss: 0.476 (data_loss: 0.445 regularization_loss: 0.031) lr: 0.0199035
# Epoch: 9800 Accuracy: 0.832 Loss: 0.486 (data_loss: 0.456 regularization_loss: 0.031) lr: 0.0199025
# Epoch: 9900 Accuracy: 0.816 Loss: 0.505 (data_loss: 0.475 regularization_loss: 0.031) lr: 0.0199015
# Epoch: 10000 Accuracy: 0.833 Loss: 0.485 (data_loss: 0.454 regularization_loss: 0.030) lr: 0.0199005
# Validation accuracy: 0.8403333333333334 Validation loss: 0.42530029369356875
