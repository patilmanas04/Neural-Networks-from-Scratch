# %%
import numpy as np
import matplotlib.pyplot as plt
from nnfs.datasets import spiral_data

# %% [markdown]
# # Building and training of neural network with backpropagation, gradient descent, learning rate decay, ADAM Optimizer and L1/L2 regularization from scratch

# %% [markdown]
# ## Load the dataset

# %%
X, y = spiral_data(samples=100, classes=3)

print(X[:5])
print(y[:5])
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="brg")
plt.show()
# Out:
# [[-0.          0.        ]
#  [ 0.00990105  0.00199988]
#  [ 0.01811783  0.00893677]
#  [-0.01218363  0.02774586]
#  [ 0.01625882  0.03698834]]
# [0 0 0 0 0]

# %% [markdown]
# ## Dense Layer

# %%
class Layer_Dense:
    def __init__(self, n_inputs, n_neurons, weight_regularizer_l1=0., bias_regularizer_l1=0., weight_regularizer_l2=0., bias_regularizer_l2=0.):
        self.n_inputs = n_inputs
        self.n_neurons = n_neurons
        self.weights = 0.01 * np.random.rand(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
        self.weight_regularizer_l1 = weight_regularizer_l1 # lambda
        self.bias_regularizer_l1 = bias_regularizer_l1 # lambda
        self.weight_regularizer_l2 = weight_regularizer_l2 # lambda
        self.bias_regularizer_l2 = bias_regularizer_l2 # lambda

    # forward method
    def forward(self, inputs):
        self.inputs = inputs
        self.output = np.dot(inputs, self.weights) + self.biases

    # backward method (backpropagation)
    def backward(self, dL_dz):
        # Gradient of loss with respect to weights
        self.dL_dw = np.dot(self.inputs.T, dL_dz)

        # Gradient of loss with respect to biases
        self.dL_db = np.sum(dL_dz, axis=0, keepdims=True)

        # Gradient of loss with respect to inputs
        self.dL_dX = np.dot(dL_dz, self.weights.T)

        # Gradients of regularization
        # L1 weights
        if self.weight_regularizer_l1>0:
            dL1 = np.ones_like(self.weights)
            dL1[self.weights < 0] = -1
            self.dL_dw += self.weight_regularizer_l1 * dL1

        # L1 biases
        if self.bias_regularizer_l1>0:
            dL1 = np.ones_like(self.biases)
            dL1[self.biases < 0] = -1
            self.dL_db += self.bias_regularizer_l1 * dL1

        # L2 weights
        if self.weight_regularizer_l2>0:
            dL2 = 2 * self.weight_regularizer_l2 * self.weights
            self.dL_dw += dL2

        # L2 biases
        if self.bias_regularizer_l2>0:
            dL2 = 2 * self.bias_regularizer_l2 * self.biases
            self.dL_db += dL2

# %% [markdown]
# ## ReLU Activation

# %%
class Activation_ReLU:
    #forward method
    def forward(self, inputs):
        self.inputs = inputs
        self.output = np.maximum(0, inputs)

    # backward method (backpropagation)
    def backward(self, dL_da):
        self.dL_dz = dL_da.copy()

        # Gradient calculation
        self.dL_dz[self.inputs <= 0] = 0

# %% [markdown]
# ## Softmax Activation

# %%
class Activation_Softmax:
    def forward(self, final_layer_outputs):
        exp_values = np.exp(final_layer_outputs - np.max(final_layer_outputs, axis=1, keepdims=True))
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)
        self.output = probabilities

# %% [markdown]
# ## Loss function

# %%
class Loss:
    def regularization_loss(self, layer):
        regularization_loss = 0

        # L1 Regularization
        if layer.weight_regularizer_l1>0:
            regularization_loss += layer.weight_regularizer_l1 * np.sum(np.abs(layer.weights))
        if layer.bias_regularizer_l1>0:
            regularization_loss += layer.bias_regularizer_l1 * np.sum(np.abs(layer.biases))

        # L2 Regularization
        if layer.weight_regularizer_l2 > 0:
            regularization_loss += layer.weight_regularizer_l2 * np.sum(layer.weights * layer.weights)
        if layer.bias_regularizer_l2 > 0:
            regularization_loss += layer.bias_regularizer_l2 * np.sum(layer.biases * layer.biases)

        return regularization_loss
    
    def calculate(self, y_pred, y_true):
        neg_log_likelihoods = self.forward(y_pred, y_true)
        avg_loss = np.mean(neg_log_likelihoods)
        return avg_loss

class Loss_CategoricalCrossEntropy(Loss):
    def forward(self, y_pred, y_true):
        y_pred_clipped = np.clip(y_pred, 1e-7, 1-1e-7)

        if len(y_true.shape) == 1:
            correct_predictions = y_pred_clipped[range(len(y_pred_clipped)), y_true]
            
        if len(y_true.shape) == 2:
            correct_predictions = np.sum(y_pred_clipped*y_true, axis=1)

        neg_log_likelihoods = -np.log(correct_predictions)
        return neg_log_likelihoods

# %% [markdown]
# ## Combined Softmax Activation and Loss function

# %%
class Activation_Softmax_Loss_CategoricalCrossEntropy:
    def __init__(self):
        self.activation_softmax = Activation_Softmax()
        self.loss_function = Loss_CategoricalCrossEntropy()

    # forward method
    def forward(self, final_layer_output, y_true):
        self.activation_softmax.forward(final_layer_output)
        self.softmax_output = self.activation_softmax.output
        self.loss = self.loss_function.calculate(self.softmax_output, y_true)

        return self.loss

    # backward method (backpropagation)
    def backward(self, y_pred, y_true):
        no_of_batches = len(y_pred)
        
        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis=1)

        self.dL_dz = self.softmax_output.copy()

        # Gradient calculation
        self.dL_dz[range(no_of_batches), y_true] -= 1

        # Normalization
        self.dL_dz = self.dL_dz / no_of_batches

# %% [markdown]
# # ADAM Optimizer (Mostly used and most important) with decaying learning rate

# %%
class Optimizer_ADAM:
    def __init__(self, learning_rate=.001, decay=0, epsilon=1e-7, beta_1=0.9, beta_2=0.999):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay # learning rate decay factor
        self.epsilon = epsilon # To avoid divide by zero
        self.beta_1 = beta_1 # momentum factor
        self.beta_2 = beta_2 # rho: cache memory decay rate
        self.epoch = 0

    def pre_update_params(self):
        # learning rate decay
        self.current_learning_rate = self.learning_rate / (1. + self.decay*self.epoch)

    def update_params(self, layer):
        if not hasattr(layer, "weight_cache"):
            layer.weight_momentums = np.zeros_like(layer.weights)
            layer.weight_cache = np.zeros_like(layer.weights)
            layer.bias_momentums = np.zeros_like(layer.biases)
            layer.bias_cache = np.zeros_like(layer.biases)
            
        layer.weight_momentums = self.beta_1*layer.weight_momentums + (1-self.beta_1)*layer.dL_dw
        layer.bias_momentums = self.beta_1*layer.bias_momentums + (1-self.beta_1)*layer.dL_db

        layer.weight_cache = self.beta_2*layer.weight_cache + (1-self.beta_2)*layer.dL_dw**2
        layer.bias_cache = self.beta_2*layer.bias_cache + (1-self.beta_2)*layer.dL_db**2

        layer.weights += -self.current_learning_rate*(layer.weight_momentums/(1-self.beta_1**(self.epoch+1))) /\
                                                     (np.sqrt(layer.weight_cache/(1-self.beta_2**(self.epoch+1))) + self.epsilon)

        layer.biases += -self.current_learning_rate*(layer.bias_momentums/(1-self.beta_1**(self.epoch+1))) /\
                                                    (np.sqrt(layer.bias_cache/(1-self.beta_2**(self.epoch+1))) + self.epsilon)

    def post_update_params(self):
        self.epoch += 1

# %% [markdown]
# ## Training the neural network

# %%
# Defining the architecture
# dense_layer1 = Layer_Dense(2, 64)
dense_layer1 = Layer_Dense(2, 64, weight_regularizer_l2=5e-4, bias_regularizer_l2=5e-4)
activation_relu = Activation_ReLU()
dense_layer2 = Layer_Dense(64, 3)
softmax_loss = Activation_Softmax_Loss_CategoricalCrossEntropy()

# SGS Optimizer
optimizer_adam = Optimizer_ADAM(learning_rate=0.02, decay=5e-7)

loss_history = []
acc_history = []

for epoch in range(10001):
    # entire forward pass
    dense_layer1.forward(X)
    activation_relu.forward(dense_layer1.output)
    dense_layer2.forward(activation_relu.output)
    softmax_loss.forward(final_layer_output=dense_layer2.output, y_true=y)

    data_loss = softmax_loss.loss
    regularization_loss = (
        softmax_loss.loss_function.regularization_loss(dense_layer1) +
        softmax_loss.loss_function.regularization_loss(dense_layer2)
    )
    loss = data_loss + regularization_loss
    loss_history.append(loss)

    predictions = np.argmax(softmax_loss.softmax_output, axis=1)
    accuracy = np.mean(predictions == y)
    acc_history.append(accuracy)

    if epoch % 100 == 0:
        print(f'Epoch: {epoch} Accuracy: {accuracy:.3f} Loss: {loss:.3f} (data_loss: {data_loss:.3f} regularization_loss: {regularization_loss:.3f}) lr: {optimizer_adam.current_learning_rate:.7f}')

    # entire backward pass (backpropagation)
    softmax_loss.backward(softmax_loss.softmax_output, y)
    dense_layer2.backward(dL_dz=softmax_loss.dL_dz)
    activation_relu.backward(dL_da=dense_layer2.dL_dX)
    dense_layer1.backward(dL_dz=activation_relu.dL_dz)

    # Applying optimizer (Gradient descent with decaying learning rate and momentum)
    optimizer_adam.pre_update_params()
    optimizer_adam.update_params(dense_layer1)
    optimizer_adam.update_params(dense_layer2)
    optimizer_adam.post_update_params()

plt.plot(loss_history)
plt.title("Graph of Loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

plt.plot(acc_history)
plt.title("Graph of Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.show()

# Testing the neural network on new data
X_test, y_test = spiral_data(samples=100, classes=3)

# forward pass with test data
dense_layer1.forward(X_test)
activation_relu.forward(dense_layer1.output)
dense_layer2.forward(activation_relu.output)
softmax_loss.forward(final_layer_output=dense_layer2.output, y_true=y_test)

loss = softmax_loss.loss
predictions = np.argmax(softmax_loss.softmax_output, axis=1)
accuracy = np.mean(predictions == y)

print(f"Validation accuracy: {accuracy} Validation loss: {loss}")
# Out:
# Epoch: 0 Accuracy: 0.317 Loss: 1.099 (data_loss: 1.099 regularization_loss: 0.000) lr: 0.0200000
# Epoch: 100 Accuracy: 0.580 Loss: 0.893 (data_loss: 0.864 regularization_loss: 0.029) lr: 0.0199990
# Epoch: 200 Accuracy: 0.707 Loss: 0.742 (data_loss: 0.684 regularization_loss: 0.058) lr: 0.0199980
# Epoch: 300 Accuracy: 0.740 Loss: 0.665 (data_loss: 0.590 regularization_loss: 0.075) lr: 0.0199970
# Epoch: 400 Accuracy: 0.803 Loss: 0.583 (data_loss: 0.494 regularization_loss: 0.089) lr: 0.0199960
# Epoch: 500 Accuracy: 0.823 Loss: 0.541 (data_loss: 0.445 regularization_loss: 0.096) lr: 0.0199950
# Epoch: 600 Accuracy: 0.833 Loss: 0.519 (data_loss: 0.422 regularization_loss: 0.097) lr: 0.0199940
# Epoch: 700 Accuracy: 0.843 Loss: 0.494 (data_loss: 0.398 regularization_loss: 0.096) lr: 0.0199930
# Epoch: 800 Accuracy: 0.847 Loss: 0.478 (data_loss: 0.383 regularization_loss: 0.095) lr: 0.0199920
# Epoch: 900 Accuracy: 0.843 Loss: 0.468 (data_loss: 0.375 regularization_loss: 0.093) lr: 0.0199910
# Epoch: 1000 Accuracy: 0.860 Loss: 0.453 (data_loss: 0.362 regularization_loss: 0.091) lr: 0.0199900
# Epoch: 1100 Accuracy: 0.863 Loss: 0.443 (data_loss: 0.354 regularization_loss: 0.090) lr: 0.0199890
# Epoch: 1200 Accuracy: 0.877 Loss: 0.436 (data_loss: 0.348 regularization_loss: 0.088) lr: 0.0199880
# Epoch: 1300 Accuracy: 0.880 Loss: 0.428 (data_loss: 0.342 regularization_loss: 0.086) lr: 0.0199870
# Epoch: 1400 Accuracy: 0.877 Loss: 0.424 (data_loss: 0.339 regularization_loss: 0.085) lr: 0.0199860
# Epoch: 1500 Accuracy: 0.880 Loss: 0.414 (data_loss: 0.331 regularization_loss: 0.083) lr: 0.0199850
# Epoch: 1600 Accuracy: 0.873 Loss: 0.410 (data_loss: 0.328 regularization_loss: 0.082) lr: 0.0199840
# Epoch: 1700 Accuracy: 0.870 Loss: 0.404 (data_loss: 0.324 regularization_loss: 0.081) lr: 0.0199830
# Epoch: 1800 Accuracy: 0.870 Loss: 0.400 (data_loss: 0.321 regularization_loss: 0.079) lr: 0.0199820
# Epoch: 1900 Accuracy: 0.877 Loss: 0.395 (data_loss: 0.316 regularization_loss: 0.078) lr: 0.0199810
# Epoch: 2000 Accuracy: 0.880 Loss: 0.391 (data_loss: 0.314 regularization_loss: 0.077) lr: 0.0199800
# Epoch: 2100 Accuracy: 0.887 Loss: 0.387 (data_loss: 0.311 regularization_loss: 0.076) lr: 0.0199790
# Epoch: 2200 Accuracy: 0.887 Loss: 0.384 (data_loss: 0.309 regularization_loss: 0.075) lr: 0.0199780
# Epoch: 2300 Accuracy: 0.880 Loss: 0.380 (data_loss: 0.306 regularization_loss: 0.074) lr: 0.0199770
# Epoch: 2400 Accuracy: 0.887 Loss: 0.379 (data_loss: 0.306 regularization_loss: 0.073) lr: 0.0199760
# Epoch: 2500 Accuracy: 0.883 Loss: 0.373 (data_loss: 0.300 regularization_loss: 0.072) lr: 0.0199750
# Epoch: 2600 Accuracy: 0.890 Loss: 0.371 (data_loss: 0.300 regularization_loss: 0.071) lr: 0.0199740
# Epoch: 2700 Accuracy: 0.880 Loss: 0.367 (data_loss: 0.297 regularization_loss: 0.070) lr: 0.0199730
# Epoch: 2800 Accuracy: 0.883 Loss: 0.364 (data_loss: 0.294 regularization_loss: 0.070) lr: 0.0199720
# Epoch: 2900 Accuracy: 0.880 Loss: 0.361 (data_loss: 0.292 regularization_loss: 0.069) lr: 0.0199711
# Epoch: 3000 Accuracy: 0.873 Loss: 0.360 (data_loss: 0.292 regularization_loss: 0.068) lr: 0.0199701
# Epoch: 3100 Accuracy: 0.897 Loss: 0.358 (data_loss: 0.291 regularization_loss: 0.068) lr: 0.0199691
# Epoch: 3200 Accuracy: 0.883 Loss: 0.355 (data_loss: 0.288 regularization_loss: 0.067) lr: 0.0199681
# Epoch: 3300 Accuracy: 0.890 Loss: 0.349 (data_loss: 0.283 regularization_loss: 0.067) lr: 0.0199671
# Epoch: 3400 Accuracy: 0.890 Loss: 0.347 (data_loss: 0.280 regularization_loss: 0.067) lr: 0.0199661
# Epoch: 3500 Accuracy: 0.887 Loss: 0.342 (data_loss: 0.275 regularization_loss: 0.067) lr: 0.0199651
# Epoch: 3600 Accuracy: 0.893 Loss: 0.338 (data_loss: 0.271 regularization_loss: 0.067) lr: 0.0199641
# Epoch: 3700 Accuracy: 0.887 Loss: 0.336 (data_loss: 0.269 regularization_loss: 0.067) lr: 0.0199631
# Epoch: 3800 Accuracy: 0.893 Loss: 0.333 (data_loss: 0.266 regularization_loss: 0.066) lr: 0.0199621
# Epoch: 3900 Accuracy: 0.900 Loss: 0.331 (data_loss: 0.265 regularization_loss: 0.066) lr: 0.0199611
# Epoch: 4000 Accuracy: 0.893 Loss: 0.331 (data_loss: 0.265 regularization_loss: 0.066) lr: 0.0199601
# Epoch: 4100 Accuracy: 0.900 Loss: 0.326 (data_loss: 0.260 regularization_loss: 0.066) lr: 0.0199591
# Epoch: 4200 Accuracy: 0.890 Loss: 0.323 (data_loss: 0.258 regularization_loss: 0.065) lr: 0.0199581
# Epoch: 4300 Accuracy: 0.893 Loss: 0.321 (data_loss: 0.256 regularization_loss: 0.065) lr: 0.0199571
# Epoch: 4400 Accuracy: 0.890 Loss: 0.328 (data_loss: 0.263 regularization_loss: 0.065) lr: 0.0199561
# Epoch: 4500 Accuracy: 0.893 Loss: 0.325 (data_loss: 0.260 regularization_loss: 0.064) lr: 0.0199551
# Epoch: 4600 Accuracy: 0.887 Loss: 0.319 (data_loss: 0.255 regularization_loss: 0.064) lr: 0.0199541
# Epoch: 4700 Accuracy: 0.890 Loss: 0.317 (data_loss: 0.253 regularization_loss: 0.063) lr: 0.0199531
# Epoch: 4800 Accuracy: 0.903 Loss: 0.313 (data_loss: 0.250 regularization_loss: 0.063) lr: 0.0199521
# Epoch: 4900 Accuracy: 0.903 Loss: 0.311 (data_loss: 0.248 regularization_loss: 0.063) lr: 0.0199511
# Epoch: 5000 Accuracy: 0.903 Loss: 0.313 (data_loss: 0.251 regularization_loss: 0.062) lr: 0.0199501
# Epoch: 5100 Accuracy: 0.893 Loss: 0.309 (data_loss: 0.246 regularization_loss: 0.062) lr: 0.0199491
# Epoch: 5200 Accuracy: 0.890 Loss: 0.308 (data_loss: 0.246 regularization_loss: 0.062) lr: 0.0199481
# Epoch: 5300 Accuracy: 0.903 Loss: 0.311 (data_loss: 0.249 regularization_loss: 0.061) lr: 0.0199472
# Epoch: 5400 Accuracy: 0.913 Loss: 0.306 (data_loss: 0.245 regularization_loss: 0.061) lr: 0.0199462
# Epoch: 5500 Accuracy: 0.900 Loss: 0.303 (data_loss: 0.242 regularization_loss: 0.061) lr: 0.0199452
# Epoch: 5600 Accuracy: 0.893 Loss: 0.302 (data_loss: 0.241 regularization_loss: 0.060) lr: 0.0199442
# Epoch: 5700 Accuracy: 0.890 Loss: 0.301 (data_loss: 0.241 regularization_loss: 0.060) lr: 0.0199432
# Epoch: 5800 Accuracy: 0.900 Loss: 0.299 (data_loss: 0.240 regularization_loss: 0.060) lr: 0.0199422
# Epoch: 5900 Accuracy: 0.897 Loss: 0.299 (data_loss: 0.239 regularization_loss: 0.059) lr: 0.0199412
# Epoch: 6000 Accuracy: 0.897 Loss: 0.297 (data_loss: 0.238 regularization_loss: 0.059) lr: 0.0199402
# Epoch: 6100 Accuracy: 0.890 Loss: 0.297 (data_loss: 0.238 regularization_loss: 0.059) lr: 0.0199392
# Epoch: 6200 Accuracy: 0.907 Loss: 0.298 (data_loss: 0.239 regularization_loss: 0.059) lr: 0.0199382
# Epoch: 6300 Accuracy: 0.897 Loss: 0.302 (data_loss: 0.243 regularization_loss: 0.058) lr: 0.0199372
# Epoch: 6400 Accuracy: 0.900 Loss: 0.292 (data_loss: 0.234 regularization_loss: 0.058) lr: 0.0199362
# Epoch: 6500 Accuracy: 0.903 Loss: 0.292 (data_loss: 0.235 regularization_loss: 0.058) lr: 0.0199352
# Epoch: 6600 Accuracy: 0.897 Loss: 0.291 (data_loss: 0.234 regularization_loss: 0.057) lr: 0.0199342
# Epoch: 6700 Accuracy: 0.897 Loss: 0.290 (data_loss: 0.233 regularization_loss: 0.057) lr: 0.0199332
# Epoch: 6800 Accuracy: 0.903 Loss: 0.287 (data_loss: 0.229 regularization_loss: 0.057) lr: 0.0199322
# Epoch: 6900 Accuracy: 0.907 Loss: 0.281 (data_loss: 0.224 regularization_loss: 0.057) lr: 0.0199312
# Epoch: 7000 Accuracy: 0.873 Loss: 0.342 (data_loss: 0.285 regularization_loss: 0.057) lr: 0.0199303
# Epoch: 7100 Accuracy: 0.903 Loss: 0.292 (data_loss: 0.231 regularization_loss: 0.061) lr: 0.0199293
# Epoch: 7200 Accuracy: 0.900 Loss: 0.288 (data_loss: 0.227 regularization_loss: 0.061) lr: 0.0199283
# Epoch: 7300 Accuracy: 0.900 Loss: 0.285 (data_loss: 0.224 regularization_loss: 0.060) lr: 0.0199273
# Epoch: 7400 Accuracy: 0.907 Loss: 0.280 (data_loss: 0.220 regularization_loss: 0.060) lr: 0.0199263
# Epoch: 7500 Accuracy: 0.903 Loss: 0.276 (data_loss: 0.216 regularization_loss: 0.060) lr: 0.0199253
# Epoch: 7600 Accuracy: 0.907 Loss: 0.275 (data_loss: 0.215 regularization_loss: 0.060) lr: 0.0199243
# Epoch: 7700 Accuracy: 0.910 Loss: 0.272 (data_loss: 0.212 regularization_loss: 0.060) lr: 0.0199233
# Epoch: 7800 Accuracy: 0.913 Loss: 0.270 (data_loss: 0.211 regularization_loss: 0.060) lr: 0.0199223
# Epoch: 7900 Accuracy: 0.913 Loss: 0.269 (data_loss: 0.209 regularization_loss: 0.060) lr: 0.0199213
# Epoch: 8000 Accuracy: 0.913 Loss: 0.267 (data_loss: 0.208 regularization_loss: 0.060) lr: 0.0199203
# Epoch: 8100 Accuracy: 0.913 Loss: 0.266 (data_loss: 0.206 regularization_loss: 0.060) lr: 0.0199193
# Epoch: 8200 Accuracy: 0.920 Loss: 0.264 (data_loss: 0.205 regularization_loss: 0.060) lr: 0.0199183
# Epoch: 8300 Accuracy: 0.920 Loss: 0.266 (data_loss: 0.206 regularization_loss: 0.060) lr: 0.0199174
# Epoch: 8400 Accuracy: 0.913 Loss: 0.261 (data_loss: 0.201 regularization_loss: 0.060) lr: 0.0199164
# Epoch: 8500 Accuracy: 0.920 Loss: 0.264 (data_loss: 0.205 regularization_loss: 0.060) lr: 0.0199154
# Epoch: 8600 Accuracy: 0.910 Loss: 0.260 (data_loss: 0.200 regularization_loss: 0.059) lr: 0.0199144
# Epoch: 8700 Accuracy: 0.920 Loss: 0.258 (data_loss: 0.198 regularization_loss: 0.059) lr: 0.0199134
# Epoch: 8800 Accuracy: 0.917 Loss: 0.256 (data_loss: 0.197 regularization_loss: 0.059) lr: 0.0199124
# Epoch: 8900 Accuracy: 0.917 Loss: 0.255 (data_loss: 0.196 regularization_loss: 0.059) lr: 0.0199114
# Epoch: 9000 Accuracy: 0.920 Loss: 0.254 (data_loss: 0.196 regularization_loss: 0.059) lr: 0.0199104
# Epoch: 9100 Accuracy: 0.913 Loss: 0.254 (data_loss: 0.195 regularization_loss: 0.058) lr: 0.0199094
# Epoch: 9200 Accuracy: 0.917 Loss: 0.253 (data_loss: 0.195 regularization_loss: 0.058) lr: 0.0199084
# Epoch: 9300 Accuracy: 0.913 Loss: 0.252 (data_loss: 0.194 regularization_loss: 0.058) lr: 0.0199074
# Epoch: 9400 Accuracy: 0.913 Loss: 0.251 (data_loss: 0.193 regularization_loss: 0.058) lr: 0.0199064
# Epoch: 9500 Accuracy: 0.913 Loss: 0.257 (data_loss: 0.200 regularization_loss: 0.057) lr: 0.0199055
# Epoch: 9600 Accuracy: 0.913 Loss: 0.251 (data_loss: 0.194 regularization_loss: 0.057) lr: 0.0199045
# Epoch: 9700 Accuracy: 0.923 Loss: 0.248 (data_loss: 0.191 regularization_loss: 0.057) lr: 0.0199035
# Epoch: 9800 Accuracy: 0.913 Loss: 0.247 (data_loss: 0.190 regularization_loss: 0.057) lr: 0.0199025
# Epoch: 9900 Accuracy: 0.923 Loss: 0.246 (data_loss: 0.190 regularization_loss: 0.057) lr: 0.0199015
# Epoch: 10000 Accuracy: 0.917 Loss: 0.245 (data_loss: 0.189 regularization_loss: 0.056) lr: 0.0199005
# Validation accuracy: 0.84 Validation loss: 0.4756110199769735

# %% [markdown]
# # Trainig with more sample points

# %%
X, y = spiral_data(samples=1000, classes=3)

# Defining the architecture
# dense_layer1 = Layer_Dense(2, 64)
dense_layer1 = Layer_Dense(2, 64, weight_regularizer_l2=5e-4, bias_regularizer_l2=5e-4)
activation_relu = Activation_ReLU()
dense_layer2 = Layer_Dense(64, 3)
softmax_loss = Activation_Softmax_Loss_CategoricalCrossEntropy()

# SGS Optimizer
optimizer_adam = Optimizer_ADAM(learning_rate=0.02, decay=5e-7)

loss_history = []
acc_history = []

for epoch in range(10001):
    # entire forward pass
    dense_layer1.forward(X)
    activation_relu.forward(dense_layer1.output)
    dense_layer2.forward(activation_relu.output)
    softmax_loss.forward(final_layer_output=dense_layer2.output, y_true=y)

    data_loss = softmax_loss.loss
    regularization_loss = (
        softmax_loss.loss_function.regularization_loss(dense_layer1) +
        softmax_loss.loss_function.regularization_loss(dense_layer2)
    )
    loss = data_loss + regularization_loss
    loss_history.append(loss)

    predictions = np.argmax(softmax_loss.softmax_output, axis=1)
    accuracy = np.mean(predictions == y)
    acc_history.append(accuracy)

    if epoch % 100 == 0:
        print(f'Epoch: {epoch} Accuracy: {accuracy:.3f} Loss: {loss:.3f} (data_loss: {data_loss:.3f} regularization_loss: {regularization_loss:.3f}) lr: {optimizer_adam.current_learning_rate:.7f}')

    # entire backward pass (backpropagation)
    softmax_loss.backward(softmax_loss.softmax_output, y)
    dense_layer2.backward(dL_dz=softmax_loss.dL_dz)
    activation_relu.backward(dL_da=dense_layer2.dL_dX)
    dense_layer1.backward(dL_dz=activation_relu.dL_dz)

    # Applying optimizer (Gradient descent with decaying learning rate and momentum)
    optimizer_adam.pre_update_params()
    optimizer_adam.update_params(dense_layer1)
    optimizer_adam.update_params(dense_layer2)
    optimizer_adam.post_update_params()

plt.plot(loss_history)
plt.title("Graph of Loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

plt.plot(acc_history)
plt.title("Graph of Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.show()

# Testing the neural network on new data
X_test, y_test = spiral_data(samples=1000, classes=3)

# forward pass with test data
dense_layer1.forward(X_test)
activation_relu.forward(dense_layer1.output)
dense_layer2.forward(activation_relu.output)
softmax_loss.forward(final_layer_output=dense_layer2.output, y_true=y_test)

loss = softmax_loss.loss
predictions = np.argmax(softmax_loss.softmax_output, axis=1)
accuracy = np.mean(predictions == y)

print(f"Validation accuracy: {accuracy} Validation loss: {loss}")
# Out:
# Epoch: 0 Accuracy: 0.304 Loss: 1.099 (data_loss: 1.099 regularization_loss: 0.000) lr: 0.0200000
# Epoch: 100 Accuracy: 0.596 Loss: 0.904 (data_loss: 0.874 regularization_loss: 0.031) lr: 0.0199990
# Epoch: 200 Accuracy: 0.723 Loss: 0.755 (data_loss: 0.689 regularization_loss: 0.066) lr: 0.0199980
# Epoch: 300 Accuracy: 0.778 Loss: 0.694 (data_loss: 0.614 regularization_loss: 0.080) lr: 0.0199970
# Epoch: 400 Accuracy: 0.795 Loss: 0.658 (data_loss: 0.573 regularization_loss: 0.085) lr: 0.0199960
# Epoch: 500 Accuracy: 0.807 Loss: 0.620 (data_loss: 0.530 regularization_loss: 0.090) lr: 0.0199950
# Epoch: 600 Accuracy: 0.823 Loss: 0.592 (data_loss: 0.499 regularization_loss: 0.094) lr: 0.0199940
# Epoch: 700 Accuracy: 0.831 Loss: 0.576 (data_loss: 0.481 regularization_loss: 0.095) lr: 0.0199930
# Epoch: 800 Accuracy: 0.831 Loss: 0.557 (data_loss: 0.462 regularization_loss: 0.095) lr: 0.0199920
# Epoch: 900 Accuracy: 0.839 Loss: 0.545 (data_loss: 0.450 regularization_loss: 0.095) lr: 0.0199910
# Epoch: 1000 Accuracy: 0.843 Loss: 0.533 (data_loss: 0.438 regularization_loss: 0.095) lr: 0.0199900
# Epoch: 1100 Accuracy: 0.837 Loss: 0.525 (data_loss: 0.431 regularization_loss: 0.094) lr: 0.0199890
# Epoch: 1200 Accuracy: 0.848 Loss: 0.512 (data_loss: 0.419 regularization_loss: 0.093) lr: 0.0199880
# Epoch: 1300 Accuracy: 0.830 Loss: 0.519 (data_loss: 0.426 regularization_loss: 0.093) lr: 0.0199870
# Epoch: 1400 Accuracy: 0.860 Loss: 0.490 (data_loss: 0.398 regularization_loss: 0.093) lr: 0.0199860
# Epoch: 1500 Accuracy: 0.860 Loss: 0.479 (data_loss: 0.387 regularization_loss: 0.093) lr: 0.0199850
# Epoch: 1600 Accuracy: 0.863 Loss: 0.471 (data_loss: 0.379 regularization_loss: 0.092) lr: 0.0199840
# Epoch: 1700 Accuracy: 0.861 Loss: 0.463 (data_loss: 0.371 regularization_loss: 0.092) lr: 0.0199830
# Epoch: 1800 Accuracy: 0.867 Loss: 0.455 (data_loss: 0.364 regularization_loss: 0.091) lr: 0.0199820
# Epoch: 1900 Accuracy: 0.868 Loss: 0.448 (data_loss: 0.358 regularization_loss: 0.090) lr: 0.0199810
# Epoch: 2000 Accuracy: 0.870 Loss: 0.442 (data_loss: 0.353 regularization_loss: 0.089) lr: 0.0199800
# Epoch: 2100 Accuracy: 0.871 Loss: 0.436 (data_loss: 0.349 regularization_loss: 0.088) lr: 0.0199790
# Epoch: 2200 Accuracy: 0.878 Loss: 0.440 (data_loss: 0.353 regularization_loss: 0.087) lr: 0.0199780
# Epoch: 2300 Accuracy: 0.872 Loss: 0.426 (data_loss: 0.340 regularization_loss: 0.086) lr: 0.0199770
# Epoch: 2400 Accuracy: 0.877 Loss: 0.421 (data_loss: 0.336 regularization_loss: 0.085) lr: 0.0199760
# Epoch: 2500 Accuracy: 0.874 Loss: 0.418 (data_loss: 0.333 regularization_loss: 0.084) lr: 0.0199750
# Epoch: 2600 Accuracy: 0.869 Loss: 0.419 (data_loss: 0.336 regularization_loss: 0.084) lr: 0.0199740
# Epoch: 2700 Accuracy: 0.880 Loss: 0.410 (data_loss: 0.327 regularization_loss: 0.083) lr: 0.0199730
# Epoch: 2800 Accuracy: 0.877 Loss: 0.407 (data_loss: 0.325 regularization_loss: 0.082) lr: 0.0199720
# Epoch: 2900 Accuracy: 0.885 Loss: 0.408 (data_loss: 0.327 regularization_loss: 0.081) lr: 0.0199711
# Epoch: 3000 Accuracy: 0.881 Loss: 0.401 (data_loss: 0.321 regularization_loss: 0.080) lr: 0.0199701
# Epoch: 3100 Accuracy: 0.881 Loss: 0.410 (data_loss: 0.331 regularization_loss: 0.079) lr: 0.0199691
# Epoch: 3200 Accuracy: 0.885 Loss: 0.397 (data_loss: 0.319 regularization_loss: 0.078) lr: 0.0199681
# Epoch: 3300 Accuracy: 0.880 Loss: 0.394 (data_loss: 0.316 regularization_loss: 0.077) lr: 0.0199671
# Epoch: 3400 Accuracy: 0.886 Loss: 0.391 (data_loss: 0.315 regularization_loss: 0.077) lr: 0.0199661
# Epoch: 3500 Accuracy: 0.882 Loss: 0.389 (data_loss: 0.313 regularization_loss: 0.076) lr: 0.0199651
# Epoch: 3600 Accuracy: 0.886 Loss: 0.387 (data_loss: 0.311 regularization_loss: 0.075) lr: 0.0199641
# Epoch: 3700 Accuracy: 0.874 Loss: 0.390 (data_loss: 0.315 regularization_loss: 0.075) lr: 0.0199631
# Epoch: 3800 Accuracy: 0.882 Loss: 0.384 (data_loss: 0.310 regularization_loss: 0.074) lr: 0.0199621
# Epoch: 3900 Accuracy: 0.885 Loss: 0.380 (data_loss: 0.307 regularization_loss: 0.073) lr: 0.0199611
# Epoch: 4000 Accuracy: 0.887 Loss: 0.382 (data_loss: 0.310 regularization_loss: 0.073) lr: 0.0199601
# Epoch: 4100 Accuracy: 0.884 Loss: 0.376 (data_loss: 0.304 regularization_loss: 0.072) lr: 0.0199591
# Epoch: 4200 Accuracy: 0.886 Loss: 0.374 (data_loss: 0.303 regularization_loss: 0.072) lr: 0.0199581
# Epoch: 4300 Accuracy: 0.885 Loss: 0.372 (data_loss: 0.301 regularization_loss: 0.071) lr: 0.0199571
# Epoch: 4400 Accuracy: 0.885 Loss: 0.371 (data_loss: 0.301 regularization_loss: 0.070) lr: 0.0199561
# Epoch: 4500 Accuracy: 0.886 Loss: 0.369 (data_loss: 0.300 regularization_loss: 0.070) lr: 0.0199551
# Epoch: 4600 Accuracy: 0.891 Loss: 0.368 (data_loss: 0.299 regularization_loss: 0.069) lr: 0.0199541
# Epoch: 4700 Accuracy: 0.887 Loss: 0.366 (data_loss: 0.297 regularization_loss: 0.069) lr: 0.0199531
# Epoch: 4800 Accuracy: 0.890 Loss: 0.363 (data_loss: 0.295 regularization_loss: 0.068) lr: 0.0199521
# Epoch: 4900 Accuracy: 0.888 Loss: 0.362 (data_loss: 0.295 regularization_loss: 0.068) lr: 0.0199511
# Epoch: 5000 Accuracy: 0.890 Loss: 0.360 (data_loss: 0.293 regularization_loss: 0.067) lr: 0.0199501
# Epoch: 5100 Accuracy: 0.890 Loss: 0.358 (data_loss: 0.291 regularization_loss: 0.067) lr: 0.0199491
# Epoch: 5200 Accuracy: 0.894 Loss: 0.359 (data_loss: 0.293 regularization_loss: 0.067) lr: 0.0199481
# Epoch: 5300 Accuracy: 0.887 Loss: 0.357 (data_loss: 0.291 regularization_loss: 0.066) lr: 0.0199472
# Epoch: 5400 Accuracy: 0.892 Loss: 0.354 (data_loss: 0.288 regularization_loss: 0.066) lr: 0.0199462
# Epoch: 5500 Accuracy: 0.893 Loss: 0.354 (data_loss: 0.289 regularization_loss: 0.066) lr: 0.0199452
# Epoch: 5600 Accuracy: 0.891 Loss: 0.351 (data_loss: 0.286 regularization_loss: 0.065) lr: 0.0199442
# Epoch: 5700 Accuracy: 0.896 Loss: 0.354 (data_loss: 0.289 regularization_loss: 0.065) lr: 0.0199432
# Epoch: 5800 Accuracy: 0.885 Loss: 0.353 (data_loss: 0.289 regularization_loss: 0.064) lr: 0.0199422
# Epoch: 5900 Accuracy: 0.894 Loss: 0.348 (data_loss: 0.284 regularization_loss: 0.064) lr: 0.0199412
# Epoch: 6000 Accuracy: 0.895 Loss: 0.346 (data_loss: 0.282 regularization_loss: 0.063) lr: 0.0199402
# Epoch: 6100 Accuracy: 0.894 Loss: 0.344 (data_loss: 0.281 regularization_loss: 0.063) lr: 0.0199392
# Epoch: 6200 Accuracy: 0.891 Loss: 0.345 (data_loss: 0.282 regularization_loss: 0.063) lr: 0.0199382
# Epoch: 6300 Accuracy: 0.894 Loss: 0.351 (data_loss: 0.288 regularization_loss: 0.062) lr: 0.0199372
# Epoch: 6400 Accuracy: 0.892 Loss: 0.343 (data_loss: 0.280 regularization_loss: 0.062) lr: 0.0199362
# Epoch: 6500 Accuracy: 0.893 Loss: 0.341 (data_loss: 0.279 regularization_loss: 0.062) lr: 0.0199352
# Epoch: 6600 Accuracy: 0.891 Loss: 0.340 (data_loss: 0.279 regularization_loss: 0.061) lr: 0.0199342
# Epoch: 6700 Accuracy: 0.893 Loss: 0.339 (data_loss: 0.278 regularization_loss: 0.061) lr: 0.0199332
# Epoch: 6800 Accuracy: 0.897 Loss: 0.337 (data_loss: 0.276 regularization_loss: 0.060) lr: 0.0199322
# Epoch: 6900 Accuracy: 0.889 Loss: 0.340 (data_loss: 0.280 regularization_loss: 0.060) lr: 0.0199312
# Epoch: 7000 Accuracy: 0.892 Loss: 0.336 (data_loss: 0.276 regularization_loss: 0.060) lr: 0.0199303
# Epoch: 7100 Accuracy: 0.897 Loss: 0.340 (data_loss: 0.280 regularization_loss: 0.059) lr: 0.0199293
# Epoch: 7200 Accuracy: 0.893 Loss: 0.334 (data_loss: 0.274 regularization_loss: 0.059) lr: 0.0199283
# Epoch: 7300 Accuracy: 0.898 Loss: 0.332 (data_loss: 0.273 regularization_loss: 0.059) lr: 0.0199273
# Epoch: 7400 Accuracy: 0.898 Loss: 0.332 (data_loss: 0.274 regularization_loss: 0.058) lr: 0.0199263
# Epoch: 7500 Accuracy: 0.893 Loss: 0.331 (data_loss: 0.273 regularization_loss: 0.058) lr: 0.0199253
# Epoch: 7600 Accuracy: 0.900 Loss: 0.330 (data_loss: 0.272 regularization_loss: 0.058) lr: 0.0199243
# Epoch: 7700 Accuracy: 0.893 Loss: 0.331 (data_loss: 0.274 regularization_loss: 0.057) lr: 0.0199233
# Epoch: 7800 Accuracy: 0.893 Loss: 0.329 (data_loss: 0.272 regularization_loss: 0.057) lr: 0.0199223
# Epoch: 7900 Accuracy: 0.899 Loss: 0.326 (data_loss: 0.270 regularization_loss: 0.057) lr: 0.0199213
# Epoch: 8000 Accuracy: 0.895 Loss: 0.327 (data_loss: 0.271 regularization_loss: 0.056) lr: 0.0199203
# Epoch: 8100 Accuracy: 0.896 Loss: 0.329 (data_loss: 0.269 regularization_loss: 0.060) lr: 0.0199193
# Epoch: 8200 Accuracy: 0.899 Loss: 0.326 (data_loss: 0.267 regularization_loss: 0.059) lr: 0.0199183
# Epoch: 8300 Accuracy: 0.900 Loss: 0.325 (data_loss: 0.267 regularization_loss: 0.059) lr: 0.0199174
# Epoch: 8400 Accuracy: 0.901 Loss: 0.325 (data_loss: 0.266 regularization_loss: 0.059) lr: 0.0199164
# Epoch: 8500 Accuracy: 0.901 Loss: 0.324 (data_loss: 0.266 regularization_loss: 0.058) lr: 0.0199154
# Epoch: 8600 Accuracy: 0.901 Loss: 0.324 (data_loss: 0.266 regularization_loss: 0.058) lr: 0.0199144
# Epoch: 8700 Accuracy: 0.901 Loss: 0.323 (data_loss: 0.266 regularization_loss: 0.058) lr: 0.0199134
# Epoch: 8800 Accuracy: 0.901 Loss: 0.323 (data_loss: 0.265 regularization_loss: 0.057) lr: 0.0199124
# Epoch: 8900 Accuracy: 0.901 Loss: 0.322 (data_loss: 0.265 regularization_loss: 0.057) lr: 0.0199114
# Epoch: 9000 Accuracy: 0.902 Loss: 0.322 (data_loss: 0.265 regularization_loss: 0.057) lr: 0.0199104
# Epoch: 9100 Accuracy: 0.901 Loss: 0.321 (data_loss: 0.265 regularization_loss: 0.056) lr: 0.0199094
# Epoch: 9200 Accuracy: 0.901 Loss: 0.321 (data_loss: 0.265 regularization_loss: 0.056) lr: 0.0199084
# Epoch: 9300 Accuracy: 0.901 Loss: 0.320 (data_loss: 0.264 regularization_loss: 0.056) lr: 0.0199074
# Epoch: 9400 Accuracy: 0.893 Loss: 0.324 (data_loss: 0.268 regularization_loss: 0.056) lr: 0.0199064
# Epoch: 9500 Accuracy: 0.898 Loss: 0.320 (data_loss: 0.265 regularization_loss: 0.055) lr: 0.0199055
# Epoch: 9600 Accuracy: 0.892 Loss: 0.334 (data_loss: 0.279 regularization_loss: 0.055) lr: 0.0199045
# Epoch: 9700 Accuracy: 0.899 Loss: 0.318 (data_loss: 0.263 regularization_loss: 0.055) lr: 0.0199035
# Epoch: 9800 Accuracy: 0.891 Loss: 0.323 (data_loss: 0.268 regularization_loss: 0.055) lr: 0.0199025
# Epoch: 9900 Accuracy: 0.901 Loss: 0.317 (data_loss: 0.263 regularization_loss: 0.054) lr: 0.0199015
# Epoch: 10000 Accuracy: 0.897 Loss: 0.318 (data_loss: 0.264 regularization_loss: 0.054) lr: 0.0199005
# Validation accuracy: 0.891 Validation loss: 0.2988648663026906
